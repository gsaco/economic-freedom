# %% [markdown]
# Special episodes robustness

# %%
import pandas as pd

from src.config import TABLES_DIR

# %%
interactions = pd.read_csv(TABLES_DIR / "episode_interactions.csv")
interactions.head()
# Out:
#              term  estimate      std_error
# 0       Intercept -0.069768  129918.052514
# 1  C(iso3)[T.ALB] -0.213573   80270.711513
# 2  C(iso3)[T.ARE] -0.434780  125712.003331
# 3  C(iso3)[T.ARG] -0.596950   71132.910103
# 4  C(iso3)[T.ARM]  0.077577  166307.126543

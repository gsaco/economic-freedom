# %% [markdown]
# Appendix: EFW components and diagnostics

# %%
import pandas as pd

from src.config import PROCESSED_DIR, DIAGNOSTICS_DIR

# %%
ef = pd.read_parquet(PROCESSED_DIR / "efw_quinquennial.parquet")
components = [c for c in ef.columns if c.startswith("efw_area")]
correlations = ef[["efw_overall"] + components].corr()
correlations
# Out:
#              efw_overall  efw_area1  efw_area2  efw_area3  efw_area4  \
# efw_overall     1.000000   0.329911   0.761568   0.785053   0.861149
# efw_area1       0.329911   1.000000  -0.011957   0.135677   0.136453
# efw_area2       0.761568  -0.011957   1.000000   0.433300   0.577444
# efw_area3       0.785053   0.135677   0.433300   1.000000   0.606106
# efw_area4       0.861149   0.136453   0.577444   0.606106   1.000000
# efw_area5       0.826196   0.135964   0.681394   0.500651   0.643429
#
#              efw_area5
# efw_overall   0.826196
# efw_area1     0.135964
# efw_area2     0.681394
# efw_area3     0.500651
# efw_area4     0.643429
# efw_area5     1.000000

# %%
try:
    diag = pd.read_csv(DIAGNOSTICS_DIR / "sdid_eu_diag_baseline.csv")
    diag.head()
except FileNotFoundError:
    "Diagnostics not found yet."
